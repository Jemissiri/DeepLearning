# %% [markdown]
# # Lab 1: Perceptrons
# ---

# %% [markdown]
# Autores:
# - Diogo Silva nº79828
# - Tiago Granja nº79845

# %% [markdown]
# Imports used

# %%
import numpy as np
import matplotlib.pyplot as plt
from   scipy import stats
